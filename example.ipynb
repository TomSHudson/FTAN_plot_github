# %% [markdown]
# # Example of using FTAN_plot module:

# %% [markdown]
# Summary:
#
# The FTAN plot effectively switches the resolution between high resolution in time (for the spectrogram plot) and high resolution in frequency (FTAN plot). Narrowing the centre frequency step increases the apparent resolution, as does increasing the number of centre frequency steps.

# %% [markdown]
# ## 1. Get data:

# %%
# Import neccessary modules:
import FTAN_plot
# Modules used only in this example (not in FTAN_plot):
import obspy
import matplotlib.pyplot as plt

# Import data for example:
st = obspy.read("S_waveform_E_2014_180_2037_event.m")
data = st[0].data # Data associated with trace of real waveform observed

# %% [markdown]
# ## 2. Plot seismic waveform:

# %%
# Plot seismic signal:
st.plot()

# %% [markdown]
# ## Plot FTAN style plot:

# %%
# Plot FTAN style plot for signal:
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
FTAN_plot.ftan_plot(data, samp_rate=500.0, centre_freq_range=[4.0,50.0], centre_freq_range_step=0.25, band_width_gau_filter=[1.00], axes=ax)
plt.show()

# %% [markdown]
# ## Plot spectrogram for comparison:

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
st[0].spectrogram(axes=ax)
ax.set_ylim([1.,50.])
ax.set_xlim([0.125,1.825])
plt.show()

# %% [markdown]
# # Plot velocity-centre frequency plot, for arbitary distance:

# %%
# Plot velocity-centre frequency plot, for arbitary distance:
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
FTAN_plot.ftan_plot(data, samp_rate=500.0, centre_freq_range=[4.0,50.0], centre_freq_range_step=0.25, band_width_gau_filter=[1.00], axes=ax, plot_type="vel-freq", event_stat_dist=1.0, vel_freq_plot_lims=[0.5,2.5])
plt.show()
# Out:
# FTAN_plot.py:122: RuntimeWarning: divide by zero encountered in divide
#   vel_array = event_stat_dist/time_array
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-017b00d0cae3> in <module>()
#       2 fig = plt.figure(figsize=(12,8))
#       3 ax = fig.add_subplot(111)
# ----> 4 FTAN_plot.ftan_plot(data, samp_rate=500.0, centre_freq_range=[4.0,50.0], centre_freq_range_step=0.25, band_width_gau_filter=[1.00], axes=ax, plot_type="vel-freq", event_stat_dist=0.5)
#       5 plt.show()
#
# /Users/tomhudson/Python/obspy_scripts/FTAN_plot_github/FTAN_plot.py in ftan_plot(data, samp_rate, centre_freq_range, centre_freq_range_step, band_width_gau_filter, plot_type, event_stat_dist, axes, log, cmap, return_ftan_data)
#     122         vel_array = event_stat_dist/time_array
#     123         y_grid, x_grid = np.meshgrid(vel_array, centre_freqs_array)
# ...
